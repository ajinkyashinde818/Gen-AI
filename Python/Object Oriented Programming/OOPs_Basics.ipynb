# %%
class Airi:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        print(f"A my Name is:",name,"and Age is:",age)

info=Airi("Ajinkya",18)
# Out:
# A my Name is: Ajinkya and Age is: 18
