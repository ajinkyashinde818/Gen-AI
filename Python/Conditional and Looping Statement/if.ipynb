# %%
age=int(input("Enter a Age:"))
if age > 18:
    print("You can drive")
else:
    print("You can not drive")
# Out:
# You can not drive

# %%
name = "Ajinkya"

if name!= "Sakshi":
    print("Not same")
else:
    print("Same")
# Out:
# Not same

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
