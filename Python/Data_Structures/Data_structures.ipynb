# %% [markdown]
# # Data Structures in Python

# %%
fruit=["Apple","Mango","Pinapple"]
print(fruit)
# Out:
# ['Apple', 'Mango', 'Pinapple']

# %%
car=["Swift","Fortuner","Ferreri","GT 650"]
print(car)
# Out:
# ['Swift', 'Fortuner', 'Ferreri', 'GT 650']
