# %% [markdown]
# # Dictionary

# %% [markdown]
# ## Dictionary in python are as the data structure are going to store a data in similar way just like in a key-value pairs

# %%
intro={
    "Name":"Ajinkya",
    "Age":18,
    "Branch":"Computer Technology",
    "Future":"AI&ML"
}
print(intro)
# Out:
# {'Name': 'Ajinkya', 'Age': 18, 'Branch': 'Computer Technology', 'Future': 'AI&ML'}
