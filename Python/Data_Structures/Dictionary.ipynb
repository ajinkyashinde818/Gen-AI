# %% [markdown]
# # Python Dictionary — Detailed Notes and Examples
#
# This notebook covers dictionary concepts from basic to advanced with runnable examples.
#
# ## What is a Dictionary?
# A dictionary stores data in **key-value pairs**.
#
# - Syntax: `{key: value}`
# - Mutable: Yes
# - Keys: Unique
# - Values: Can repeat
# - Access: Usually by key

# %%
student = {
    "name": "Ajinkya",
    "age": 21,
    "branch": "Computer Technology",
    "marks": 90
}

print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'branch': 'Computer Technology', 'marks': 90}

# %% [markdown]
# ## 1. Key and Value
#
# In the dictionary below:
# - `"name"` is a key and `"Ajinkya"` is its value.
# - `"age"` is a key and `21` is its value.

# %%
student = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90
}

print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'marks': 90}

# %% [markdown]
# ## 2. Accessing Values Using Keys

# %%
print(student["name"])
print(student["marks"])
# Out:
# Ajinkya
# 90

# %% [markdown]
# ## 3. Dictionary is Mutable
#
# A dictionary can be changed after creation.

# %%
student["marks"] = 95
print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'marks': 95}

# %% [markdown]
# ## 4. Adding a New Key-Value Pair

# %%
student["branch"] = "Computer Technology"
print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'marks': 95, 'branch': 'Computer Technology'}

# %% [markdown]
# ## 5. Change vs Add
#
# - Existing key → update its value
# - New key → add a new pair

# %%
student["marks"] = 98       # Update
student["city"] = "Sangamner"  # Add
print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'marks': 98, 'branch': 'Computer Technology', 'city': 'Sangamner'}

# %% [markdown]
# ## 6. `get()` Method

# %%
print(student.get("name"))
print(student.get("phone"))
print(student.get("phone", "Not Available"))
# Out:
# Ajinkya
# None
# Not Available

# %% [markdown]
# ## 7. `keys()` Method

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'marks', 'branch', 'city'])

# %% [markdown]
# ## 8. `values()` Method

# %%
print(student.values())
# Out:
# dict_values(['Ajinkya', 21, 98, 'Computer Technology', 'Sangamner'])

# %% [markdown]
# ## 9. `items()` Method

# %%
print(student.items())
# Out:
# dict_items([('name', 'Ajinkya'), ('age', 21), ('marks', 98), ('branch', 'Computer Technology'), ('city', 'Sangamner')])

# %% [markdown]
# ## 10. Loop Through Dictionary Keys

# %%
for x in student:
    print(x)
# Out:
# name
# age
# marks
# branch
# city

# %% [markdown]
# ## 11. Loop Through Values

# %%
for x in student.values():
    print(x)
# Out:
# Ajinkya
# 21
# 98
# Computer Technology
# Sangamner

# %% [markdown]
# ## 12. Loop Through Keys and Values Together

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name Ajinkya
# age 21
# marks 98
# branch Computer Technology
# city Sangamner

# %% [markdown]
# ## 13. Check Whether a Key Exists

# %%
if "name" in student:
    print("Name exists")

print("Ajinkya" in student)
print("Ajinkya" in student.values())
# Out:
# Name exists
# False
# True

# %% [markdown]
# ## 14. Remove Item Using `pop()`

# %%
data = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90
}

data.pop("age")
print(data)
# Out:
# {'name': 'Ajinkya', 'marks': 90}

# %% [markdown]
# ## 15. Remove Last Inserted Pair Using `popitem()`

# %%
data = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90
}

data.popitem()
print(data)
# Out:
# {'name': 'Ajinkya', 'age': 21}

# %% [markdown]
# ## 16. Delete an Item Using `del`

# %%
data = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90
}

del data["age"]
print(data)
# Out:
# {'name': 'Ajinkya', 'marks': 90}

# %% [markdown]
# ## 17. Remove All Items Using `clear()`

# %%
data = {
    "name": "Ajinkya",
    "age": 21
}

data.clear()
print(data)
# Out:
# {}

# %% [markdown]
# ## 18. `update()` Method

# %%
student = {
    "name": "Ajinkya",
    "age": 21
}

student.update({
    "age": 22,
    "marks": 90
})

print(student)
# Out:
# {'name': 'Ajinkya', 'age': 22, 'marks': 90}

# %% [markdown]
# ## 19. Duplicate Keys Are Not Allowed
#
# If a key appears again, the later value replaces the earlier value.

# %%
student = {
    "name": "Ajinkya",
    "marks": 80,
    "marks": 95
}

print(student)
# Out:
# {'name': 'Ajinkya', 'marks': 95}

# %% [markdown]
# ## 20. Duplicate Values Are Allowed

# %%
students = {
    "Ajinkya": 90,
    "Rahul": 90,
    "Sakshi": 90
}

print(students)
# Out:
# {'Ajinkya': 90, 'Rahul': 90, 'Sakshi': 90}

# %% [markdown]
# ## 21. Different Data Types as Values

# %%
student = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90.5,
    "passed": True,
    "subjects": ["Python", "Java"]
}

print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'marks': 90.5, 'passed': True, 'subjects': ['Python', 'Java']}

# %% [markdown]
# ## 22. Rules for Dictionary Keys
#
# Common valid keys include strings, integers, and suitable tuples.
# A list cannot be used as a dictionary key.

# %%
data = {
    "name": "Ajinkya",
    1: "One",
    (10, 20): "Point"
}

print(data)
# Out:
# {'name': 'Ajinkya', 1: 'One', (10, 20): 'Point'}

# %% [markdown]
# ## 23. Nested Dictionary

# %%
students = {
    "student1": {
        "name": "Ajinkya",
        "marks": 90
    },
    "student2": {
        "name": "Rahul",
        "marks": 80
    }
}

print(students["student1"]["name"])
print(students["student2"]["marks"])
# Out:
# Ajinkya
# 80

# %% [markdown]
# ## 24. List of Dictionaries

# %%
students = [
    {"name": "Ajinkya", "marks": 90},
    {"name": "Rahul", "marks": 80},
    {"name": "Sakshi", "marks": 95}
]

print(students[1]["name"])
# Out:
# Rahul

# %% [markdown]
# ## 25. Dictionary Comprehension

# %%
squares = {x: x * x for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### Dictionary Comprehension Pattern
#
# ```python
# {key_expression: value_expression for item in iterable}
# ```

# %% [markdown]
# ## 26. Copying a Dictionary

# %%
student = {
    "name": "Ajinkya",
    "marks": 90
}

new_student = student.copy()
print(new_student)
# Out:
# {'name': 'Ajinkya', 'marks': 90}

# %% [markdown]
# ## 27. Dictionary Length

# %%
student = {
    "name": "Ajinkya",
    "age": 21,
    "marks": 90
}

print(len(student))
# Out:
# 3

# %% [markdown]
# ## 28. List vs Tuple vs Dictionary
#
# | Feature | List | Tuple | Dictionary |
# |---|---|---|---|
# | Syntax | `[]` | `()` | `{key: value}` |
# | Data style | Values | Values | Key-value pairs |
# | Mutable | Yes | No | Yes |
# | Access | Index | Index | Key |
# | Duplicates | Yes | Yes | Keys: No, Values: Yes |
#
# ## Final Summary
#
# A dictionary is a **mutable data structure** that stores information in **key-value pairs**.
#
# Important concepts:
# 1. Create a dictionary
# 2. Access values using keys
# 3. Add and update items
# 4. Use `get()`
# 5. Use `keys()`, `values()`, and `items()`
# 6. Loop through dictionaries
# 7. Remove items
# 8. Nested dictionaries
# 9. List of dictionaries
# 10. Dictionary comprehension

# %%
'''

Problem: Student Result Management System

Create this dictionary:

student = {
    "name": "Ajinkya",
    "age": 20,
    "branch": "Computer Technology",
    "marks": [85, 72, 90, 66, 88]
}

Complete these tasks:

1.Print only the student's name using the key "name".
2.Print the third mark from the "marks" list.
3.Change the age from 20 to 21.

4.Add a new key-value pair:

"city": "Sangamner"
5.Add 95 to the marks list.
6.Print all dictionary keys using keys().
7.Print all dictionary values using values().
8.Print every key and value using a loop with items().
9.Create a new list containing only marks greater than or equal to 80 using list comprehension.
10.Create a shallow copy of the student dictionary named:
student_copy

Then change:

student_copy["marks"][0] = 100

Print both student and student_copy, and observe what happens.

Bonus challenge

Using dictionary comprehension, create this dictionary:

{
    1: 1,
    2: 4,
    3: 9,
    4: 16,
    5: 25
}
'''

student = {
    "name": "Ajinkya",
    "age": 20,
    "branch": "Computer Technology",
    "marks": [85, 72, 90, 66, 88]
}

# %%
# 1.
print(student['name'])
# Out:
# Ajinkya

# %%
# 2.
print(student["marks"][2])
# Out:
# 90

# %%
# 3.
update=student['age']=21
print(update)
# Out:
# 21

# %%
# 4.
new=student['city']='Sangamner'
print(new)
# Out:
# Sangamner

# %%
# 5.
print(student['marks'].append(95))
print(student)
print(student['marks'].remove(95))
# Out:
# None
# {'name': 'Ajinkya', 'age': 21, 'branch': 'Computer Technology', 'marks': [85, 72, 90, 66, 88, 95, 95, 95, 95, 95], 'city': 'Sangamner'}
# None

# %%
# 6.
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'branch', 'marks', 'city'])

# %%
# 7.
print(student.values())
# Out:
# dict_values(['Ajinkya', 21, 'Computer Technology', [85, 72, 90, 66, 88, 95, 95, 95, 95], 'Sangamner'])

# %%
# 8.
for key,value in student.items():
    print(key,value)
# Out:
# name Ajinkya
# age 21
# branch Computer Technology
# marks [85, 72, 90, 66, 88, 95, 95, 95, 95]
# city Sangamner

# %%
# 9.
student['marks']=[x for x in student['marks'] if x>= 80]
print(student)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'branch': 'Computer Technology', 'marks': [85, 90, 88, 95, 95, 95, 95], 'city': 'Sangamner'}

# %%
# 10.
student_copy=student.copy()
student_copy["marks"][0] = 100

print(student)
print(student_copy)
# Out:
# {'name': 'Ajinkya', 'age': 21, 'branch': 'Computer Technology', 'marks': [100, 90, 88, 95, 95, 95, 95], 'city': 'Sangamner'}
# {'name': 'Ajinkya', 'age': 21, 'branch': 'Computer Technology', 'marks': [100, 90, 88, 95, 95, 95, 95], 'city': 'Sangamner'}

# %%
# Bonous 
square={x: x*x for x in range(1,6)}
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
