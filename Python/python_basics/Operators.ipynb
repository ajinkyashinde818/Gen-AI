# %% [markdown]
# # Operator

# %% [markdown]
# ## Operators is help in to apply a operations a on a give operands.

# %%
a=5;b=2
print(a+b)
# Out:
# 7

# %% [markdown]
# # Types of Operators
#
# | Operator Type | Purpose |
# |---|---|
# | Arithmetic | Mathematical operations |
# | Assignment | Assign values |
# | Comparison | Compare values |
# | Logical | Combine conditions |
# | Identity | Check object identity |
# | Membership | Check membership |
# | Bitwise | Binary operations |

# %% [markdown]
# # 1. Arithmetic Operators
#
# | Operator | Meaning        | Example   |
# | -------- | -------------- | --------- |
# | `+`      | Addition       | `10 + 5`  |
# | `-`      | Subtraction    | `10 - 5`  |
# | `*`      | Multiplication | `10 * 5`  |
# | `/`      | Division       | `10 / 5`  |
# | `//`     | Floor Division | `10 // 3` |
# | `%`      | Modulus        | `10 % 3`  |
# | `**`     | Power          | `2 ** 3`  |

# %%
x = 10
y = 3

print("Addition:", x + y)
print("Subtraction:", x - y)
print("Multiplication:", x * y)
print("Division:", x / y)
print("Floor Division:", x // y)
print("Modulus:", x % y)
print("Power:", x ** y)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Power: 1000

# %% [markdown]
# # 2. Assignment Operators
#
# | Operator | Example  |
# | -------- | -------- |
# | `=`      | `x = 5`  |
# | `+=`     | `x += 2` |
# | `-=`     | `x -= 2` |
# | `*=`     | `x *= 2` |
# | `/=`     | `x /= 2` |

# %%
x = 10

x += 5
print("x += 5:", x)

x -= 2
print("x -= 2:", x)

x *= 2
print("x *= 2:", x)

x /= 2
print("x /= 2:", x)
# Out:
# x += 5: 15
# x -= 2: 13
# x *= 2: 26
# x /= 2: 13.0

# %% [markdown]
# # 3. Comparison Operators
#
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `==`     | Equal            |
# | `!=`     | Not Equal        |
# | `>`      | Greater than     |
# | `<`      | Less than        |
# | `>=`     | Greater or equal |
# | `<=`     | Less or equal    |

# %%
x = 10
y = 5

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # 4. Logical Operators
#
# | Operator | Meaning              |
# | -------- | -------------------- |
# | `and`    | Both conditions true |
# | `or`     | Any one true         |
# | `not`    | Reverse condition    |

# %%
age = 18

print(age > 15 and age < 25)
print(age > 20 or age < 25)
print(not(age > 20))
# Out:
# True
# True
# True

# %% [markdown]
# # 5. Identity Operators
#
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `is`     | Same object      |
# | `is not` | Different object |

# %%
x = [1, 2]
y = x
z = [1, 2]

print(x is y)
print(x is z)
print(x is not z)
# Out:
# True
# False
# True

# %% [markdown]
# # 6. Membership Operators
#
# | Operator | Meaning     |
# | -------- | ----------- |
# | `in`     | Present     |
# | `not in` | Not present |

# %%
nums = [1, 2, 3, 4]

print(2 in nums)
print(10 in nums)
print(5 not in nums)
# Out:
# True
# False
# True

# %% [markdown]
# # 7. Bitwise Operators
#
# | Operator | Meaning     |    |
# | -------- | ----------- | -- |
# | `&`      | AND         |    |
# | `        | `           | OR |
# | `^`      | XOR         |    |
# | `~`      | NOT         |    |
# | `<<`     | Left Shift  |    |
# | `>>`     | Right Shift |    |

# %%
x = 5
y = 3

print(x & y)
print(x | y)
print(x ^ y)
print(~x)
print(x << 1)
print(x >> 1)
# Out:
# 1
# 7
# 6
# -6
# 10
# 2

# %% [markdown]
# # Operator Precedence

# %%
x = 10 + 5 * 2

print(x)
# Out:
# 20

# %% [markdown]
# # Final Summary
#
# Python operators are symbols used to perform operations on variables and values.

# %%
# Simple Calculator

num1=int(input("Enter a Number 1:"))
num2=int(input("Enter a Number 2:"))
operator=input("Enter a Operator (+,-,*,/):")

if operator=="+":
    print("The Addition is:",num1+num2)

if operator=="-":
    print("The Substraction is:",num1-num2)

if operator=="*":
    print("The Multiplication is:",a*b)

if operator=="/":
    print("The Division is:",num1/num2)
# Out:
# The Addition is: 6

# %%
'''
Smart Online Shopping System

Create a Python program for an online shopping bill system.

Requirements

Take input from user:

Customer Name
Product Name
Product Price
Product Quantity
Is Premium Member (True/False)
Coupon Code
Payment Method

'''
name = input("Enter a Name: ")

product = input("Enter product name: ")
quantity = int(input("Enter a Quantity: "))

price = 500

total = price * quantity

gst = (total * 18) / 100

final_amount = total + gst

premium = input("Customer is Premium member (True or False): ")

discount = 0

if premium == "True":
    discount = (final_amount * 10) / 100

coupon = ["SAVE10", "SUPER20", "MEGA50"]

entercoupon = input("Enter a Coupon Code: ")

finalbill = final_amount - discount

if entercoupon in coupon:
    finalbill = finalbill - 100

print("---------------- SHOPPING BILL ----------------")

print("Customer Name:", name)

print("Product:", product)

print("Quantity:", quantity)

print("Subtotal:", total)

print("GST:", gst)

print("Premium Discount:", discount)

print("Final BILL:", finalbill)
# Out:
# ---------------- SHOPPING BILL ----------------
# Customer Name: Ajinkya
# Product: Shoes
# Quantity: 2
# Subtotal: 1000
# GST: 180.0
# Premium Discount: 0
# Final BILL: 1180.0
