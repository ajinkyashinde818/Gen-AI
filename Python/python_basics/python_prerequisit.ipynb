# %% [markdown]
# # Python Requirement

# %% [markdown]
# Hello

# %%
print("Hello World !")
# Out:
# Hello World !

# %%
print("This is a simple Python script.")
# Out:
# This is a simple Python script.
