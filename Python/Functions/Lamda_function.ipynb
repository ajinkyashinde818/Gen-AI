# %% [markdown]
# # Lambda function

# %% [markdown]
# ## A Lambda function is a such type of one liner function and it defined by lamda keyword

# %% [markdown]
# ### Syntax:
#     lambda argument:expression
#
#     lambda:-A such type of a keyword to define a lambda function
#     argument:- A user input value.
#     expression:- A Logic based on problem

# %%
square=lambda x:x**2
print(square(5))
# Out:
# 25
